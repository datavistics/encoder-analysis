# %%
# %load_ext autoreload
# %autoreload 2

# %%
from huggingface_hub import login, whoami

login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# DATASET CONFIG
DATASET='openbmb/RLAIF-V-Dataset'
MODEL='vidore/colqwen2-v1.0-merged'
MIN_TOKENS=50
MAX_TOKENS=8000
SAMPLES=1_000
MAX_VUS = 600
IMAGE_COLUMN='image'
DATASET_PATH='data/vision-embedding-dataset.jsonl'
K6_BIN = "/usr/bin/k6"

HUB_DATASET_PATH = f'{whoami()["name"]}/vision-embedding-ie-optimization'

# %%
from datasets import load_dataset
from transformers import AutoTokenizer
from src.process_dataset import pil_to_base64, save_dataset
from loguru import logger
import json

try:
    # Check if the file exists and count lines
    with open(DATASET_PATH, "r", encoding="utf-8") as f:
        line_count = sum(1 for _ in f)

    if line_count != SAMPLES:
        raise ValueError(f"Dataset has {line_count} rows instead of {SAMPLES}. Reprocessing...")

    logger.info(f"Loaded dataset from JSON with {SAMPLES} samples.")

    # Now load the dataset since we confirmed the row count is correct
    with open(DATASET_PATH, "r", encoding="utf-8") as f:
        dataset = json.load(f)

except (FileNotFoundError, ValueError):
    logger.warning("Dataset missing, incorrect size, or corrupted. Reprocessing...")

    dataset = load_dataset(DATASET, 'default', split=f"train[:{SAMPLES}]")
    dataset = dataset.map(lambda x: {"image_b64": pil_to_base64(x[IMAGE_COLUMN])})

    save_dataset(dataset.select_columns(["image_b64"]), DATASET_PATH)
    logger.info(f"Saved new dataset with {SAMPLES} samples.")
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# 2025-01-30 08:26:49.336 | INFO     | __main__:<module>:15 - Loaded dataset from JSON with 1000 samples.
# 2025-01-30 08:26:50.299 | WARNING  | __main__:<module>:22 - Dataset missing, incorrect size, or corrupted. Reprocessing...
# 2025-01-30 08:26:55.957 | INFO     | src.process_dataset:save_dataset:56 - Saved dataset to data/vision-embedding-dataset.jsonl in JSONL format
# 2025-01-30 08:26:55.977 | INFO     | __main__:<module>:28 - Saved new dataset with 1000 samples.

# %%
from dataclasses import dataclass, field, asdict
from typing import Dict

@dataclass
class InstanceConfig:
    repository: str
    accelerator: str
    instance_size: str
    instance_type: str
    custom_image: Dict[str, str]  # Dict of str -> str
    vendor: str
    region: str

@dataclass
class InfinityConfig:
    INFINITY_PORT: str = "80"
    INFINITY_ENGINE: str = "torch"
    INFINITY_BATCH_SIZE: str = "16"
    INFINITY_DTYPE: str = "auto"
    INFINITY_EMBEDDING_DTYPE: str = "float32"
    INFINITY_POOLING_METHOD: str = "auto"
    INFINITY_COMPILE: str = 'false'
    INFINITY_BETTERTRANSFORMER: str = 'false'
    INFINITY_MODEL_ID: str = "/repository"

    def to_dict(self) -> Dict[str, str]:
        """Converts the dataclass to a dictionary representation."""
        return asdict(self)

@dataclass
class ImageConfig:
    health_route: str = "/health"
    url: str = "michaelf34/infinity:0.0.75"
    env: InfinityConfig = field(default_factory=InfinityConfig)

# %%
def set_env(batch_size: int, image_config: ImageConfig) -> Dict[str, str]:
    config = asdict(image_config)
    config['env']["INFINITY_BATCH_SIZE"] = str(batch_size)
    return config

# %% [markdown]
# # Experiments

# %%
from src.deployment import deploy_endpoint
# ?deploy_endpoint
# Out:
# Signature: deploy_endpoint(instance_config, endpoint_name, wait=False)
# Docstring: Creates and deploys an inference endpoint using the given instance configuration.
# File:      ~/encoder-analysis/src/deployment.py
# Type:      function

# %% [markdown]
# ## GPUs

# %%
instance_config_experiment_dicts = [
    {
        'accelerator': 'gpu',
        'instance_size': 'x1',
        'instance_type': 'nvidia-l4',
        'vendor': 'aws',
        'region': 'us-east-1',
    },
]
instance_config_experiments = [InstanceConfig(repository=MODEL, **instance_config_experiment_dict, custom_image=None) for instance_config_experiment_dict in instance_config_experiment_dicts]

# %%
import copy
from pathlib import Path
from time import sleep

from loguru import logger

from src.k6 import call_k6, optimal_vus

template_file = "vision-embedding-analysis.js.j2"
output_file = Path("./generated").resolve()/"vision-embedding-analysis.js"

start_vus = 1
batch_sizes = [1, 2, 4, 8, 16, 32]

for og_instance_config_experiment in instance_config_experiments:
    endpoints = []
    for batch_size in batch_sizes:
        # Configure Infinity Settings, pass them up to the image
        infinty_config = InfinityConfig(INFINITY_BATCH_SIZE=str(batch_size))
        image_config = ImageConfig(env=infinty_config)

        # Add the image to the HW instance
        instance_config_experiment = copy.deepcopy(og_instance_config_experiment)
        instance_config_experiment.custom_image = image_config

        # Deploy the endpoint
        logger.info(f'Creating endpoint with Batch Size:\t{batch_size}')
        vendor = instance_config_experiment.vendor
        endpoint = deploy_endpoint(instance_config_experiment, endpoint_name=f'ea-{vendor}-{batch_size}', wait=False)
        endpoints.append(endpoint)

    endpoints[0].wait()
    
    for endpoint in endpoints:
        endpoint.fetch()
        batch_size = endpoint.__dict__["raw"]["model"]["env"]["INFINITY_BATCH_SIZE"]
        vendor = endpoint.__dict__["raw"]["provider"]["vendor"]
        instance_type = endpoint.__dict__["raw"]["compute"]["instanceType"]
        logger.success(f'Endpoint is ready!')
        logger.info(f'\tVendor: {vendor}')
        logger.info(f'\tInstance: {instance_type}')
        logger.info(f'\tBatch Size: {batch_size}')

        args_dict = dict(
            endpoint=endpoint,
            text_column=IMAGE_COLUMN,
            total_requests=SAMPLES,
            template_file=template_file,
            output_file=output_file,
            dataset_path=DATASET_PATH,
            k6_bin=K6_BIN
        )

        optimal_vus(max_vus=MAX_VUS, args_dict=args_dict, start_vus=start_vus)
        endpoint.delete()
        sleep(5)
# Out:
# 2025-01-30 08:26:56.126 | INFO     | __main__:<module>:27 - Creating endpoint with Batch Size:	1
# 2025-01-30 08:26:56.402 | SUCCESS  | src.deployment:deploy_endpoint:15 - Re-using Endpoint: hw=nvidia-l4	bs=1
# 2025-01-30 08:26:56.402 | INFO     | __main__:<module>:27 - Creating endpoint with Batch Size:	2
# 2025-01-30 08:26:56.528 | SUCCESS  | src.deployment:deploy_endpoint:15 - Re-using Endpoint: hw=nvidia-l4	bs=2
# 2025-01-30 08:26:56.528 | INFO     | __main__:<module>:27 - Creating endpoint with Batch Size:	4
# 2025-01-30 08:26:56.682 | SUCCESS  | src.deployment:deploy_endpoint:15 - Re-using Endpoint: hw=nvidia-l4	bs=4
# 2025-01-30 08:26:56.683 | INFO     | __main__:<module>:27 - Creating endpoint with Batch Size:	8
# 2025-01-30 08:26:56.879 | SUCCESS  | src.deployment:deploy_endpoint:15 - Re-using Endpoint: hw=nvidia-l4	bs=8
# 2025-01-30 08:26:56.880 | INFO     | __main__:<module>:27 - Creating endpoint with Batch Size:	16
# 2025-01-30 08:26:56.998 | SUCCESS  | src.deployment:deploy_endpoint:15 - Re-using Endpoint: hw=nvidia-l4	bs=16
# 2025-01-30 08:26:56.998 | INFO     | __main__:<module>:27 - Creating endpoint with Batch Size:	32
# 2025-01-30 08:26:57.142 | SUCCESS  | src.deployment:deploy_endpoint:15 - Re-using Endpoint: hw=nvidia-l4	bs=32
# 2025-01-30 08:26:57.175 | SUCCESS  | __main__:<module>:39 - Endpoint is ready!
# 2025-01-30 08:26:57.175 | INFO     | __main__:<module>:40 - 	Vendor: aws
# 2025-01-30 08:26:57.176 | INFO     | __main__:<module>:41 - 	Instance: nvidia-l4
# 2025-01-30 08:26:57.176 | INFO     | __main__:<module>:42 - 	Batch Size: 1
# 2025-01-30 08:26:57.176 | INFO     | src.k6:optimal_vus:91 - Starting exponential search for optimal VUs
# 2025-01-30 08:26:57.176 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 1
# 2025-01-30 08:28:20.707 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_1_1.json
# 2025-01-30 08:28:20.708 | INFO     | src.k6:optimal_vus:96 - Throughput for 1 VUs: 2.99 req/sec
# 2025-01-30 08:28:20.708 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 2
# 2025-01-30 08:29:44.068 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_1_2.json
# 2025-01-30 08:29:44.068 | INFO     | src.k6:optimal_vus:96 - Throughput for 2 VUs: 4.59 req/sec
# 2025-01-30 08:29:44.069 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 4
# 2025-01-30 08:31:07.917 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_1_4.json
# 2025-01-30 08:31:07.918 | INFO     | src.k6:optimal_vus:96 - Throughput for 4 VUs: 4.83 req/sec
# 2025-01-30 08:31:07.918 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 8
# 2025-01-30 08:32:32.864 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_1_8.json
# 2025-01-30 08:32:32.865 | INFO     | src.k6:optimal_vus:96 - Throughput for 8 VUs: 4.77 req/sec
# 2025-01-30 08:32:32.865 | INFO     | src.k6:optimal_vus:100 - Throughput improvement is less than 2%, stopping exponential search.
# 2025-01-30 08:32:32.865 | INFO     | src.k6:optimal_vus:108 - Starting binary search refinement
# 2025-01-30 08:32:32.866 | INFO     | src.k6:optimal_vus:112 - Testing with VUs: 6
# 2025-01-30 08:33:57.322 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_1_6.json
# 2025-01-30 08:33:57.323 | INFO     | src.k6:optimal_vus:120 - Throughput did not improve with 6 VUs
# 2025-01-30 08:33:57.323 | INFO     | src.k6:optimal_vus:112 - Testing with VUs: 4
# 2025-01-30 08:33:57.326 | INFO     | src.k6:call_k6:42 - results file /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_1_4.json already exists
# 2025-01-30 08:33:57.327 | INFO     | src.k6:optimal_vus:120 - Throughput did not improve with 4 VUs
# 2025-01-30 08:33:57.327 | INFO     | src.k6:optimal_vus:123 - Optimal VUs: 4
# 2025-01-30 08:34:02.535 | SUCCESS  | __main__:<module>:39 - Endpoint is ready!
# 2025-01-30 08:34:02.536 | INFO     | __main__:<module>:40 - 	Vendor: aws
# 2025-01-30 08:34:02.536 | INFO     | __main__:<module>:41 - 	Instance: nvidia-l4
# 2025-01-30 08:34:02.536 | INFO     | __main__:<module>:42 - 	Batch Size: 2
# 2025-01-30 08:34:02.537 | INFO     | src.k6:optimal_vus:91 - Starting exponential search for optimal VUs
# 2025-01-30 08:34:02.537 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 1
# 2025-01-30 08:35:24.947 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_2_1.json
# 2025-01-30 08:35:24.947 | INFO     | src.k6:optimal_vus:96 - Throughput for 1 VUs: 2.99 req/sec
# 2025-01-30 08:35:24.948 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 2
# 2025-01-30 08:36:48.678 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_2_2.json
# 2025-01-30 08:36:48.679 | INFO     | src.k6:optimal_vus:96 - Throughput for 2 VUs: 4.60 req/sec
# 2025-01-30 08:36:48.679 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 4
# 2025-01-30 08:38:12.812 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_2_4.json
# 2025-01-30 08:38:12.813 | INFO     | src.k6:optimal_vus:96 - Throughput for 4 VUs: 4.83 req/sec
# 2025-01-30 08:38:12.814 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 8
# 2025-01-30 08:39:36.823 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_2_8.json
# 2025-01-30 08:39:36.824 | INFO     | src.k6:optimal_vus:96 - Throughput for 8 VUs: 4.40 req/sec
# 2025-01-30 08:39:36.824 | INFO     | src.k6:optimal_vus:100 - Throughput improvement is less than 2%, stopping exponential search.
# 2025-01-30 08:39:36.824 | INFO     | src.k6:optimal_vus:108 - Starting binary search refinement
# 2025-01-30 08:39:36.825 | INFO     | src.k6:optimal_vus:112 - Testing with VUs: 6
# 2025-01-30 08:41:00.703 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_2_6.json
# 2025-01-30 08:41:00.704 | INFO     | src.k6:optimal_vus:120 - Throughput did not improve with 6 VUs
# 2025-01-30 08:41:00.704 | INFO     | src.k6:optimal_vus:112 - Testing with VUs: 4
# 2025-01-30 08:41:00.707 | INFO     | src.k6:call_k6:42 - results file /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_2_4.json already exists
# 2025-01-30 08:41:00.708 | INFO     | src.k6:optimal_vus:120 - Throughput did not improve with 4 VUs
# 2025-01-30 08:41:00.708 | INFO     | src.k6:optimal_vus:123 - Optimal VUs: 4
# 2025-01-30 08:41:05.980 | SUCCESS  | __main__:<module>:39 - Endpoint is ready!
# 2025-01-30 08:41:05.980 | INFO     | __main__:<module>:40 - 	Vendor: aws
# 2025-01-30 08:41:05.981 | INFO     | __main__:<module>:41 - 	Instance: nvidia-l4
# 2025-01-30 08:41:05.981 | INFO     | __main__:<module>:42 - 	Batch Size: 4
# 2025-01-30 08:41:05.981 | INFO     | src.k6:optimal_vus:91 - Starting exponential search for optimal VUs
# 2025-01-30 08:41:05.982 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 1
# 2025-01-30 08:42:29.955 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_4_1.json
# 2025-01-30 08:42:29.956 | INFO     | src.k6:optimal_vus:96 - Throughput for 1 VUs: 2.99 req/sec
# 2025-01-30 08:42:29.956 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 2
# 2025-01-30 08:43:53.839 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_4_2.json
# 2025-01-30 08:43:53.840 | INFO     | src.k6:optimal_vus:96 - Throughput for 2 VUs: 4.56 req/sec
# 2025-01-30 08:43:53.840 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 4
# 2025-01-30 08:45:16.324 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_4_4.json
# 2025-01-30 08:45:16.325 | INFO     | src.k6:optimal_vus:96 - Throughput for 4 VUs: 4.99 req/sec
# 2025-01-30 08:45:16.326 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 8
# 2025-01-30 08:46:41.507 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_4_8.json
# 2025-01-30 08:46:41.508 | INFO     | src.k6:optimal_vus:96 - Throughput for 8 VUs: 4.32 req/sec
# 2025-01-30 08:46:41.509 | INFO     | src.k6:optimal_vus:100 - Throughput improvement is less than 2%, stopping exponential search.
# 2025-01-30 08:46:41.509 | INFO     | src.k6:optimal_vus:108 - Starting binary search refinement
# 2025-01-30 08:46:41.510 | INFO     | src.k6:optimal_vus:112 - Testing with VUs: 6
# 2025-01-30 08:48:06.298 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_4_6.json
# 2025-01-30 08:48:06.299 | INFO     | src.k6:optimal_vus:120 - Throughput did not improve with 6 VUs
# 2025-01-30 08:48:06.299 | INFO     | src.k6:optimal_vus:112 - Testing with VUs: 4
# 2025-01-30 08:48:06.302 | INFO     | src.k6:call_k6:42 - results file /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_4_4.json already exists
# 2025-01-30 08:48:06.303 | INFO     | src.k6:optimal_vus:120 - Throughput did not improve with 4 VUs
# 2025-01-30 08:48:06.303 | INFO     | src.k6:optimal_vus:123 - Optimal VUs: 4
# 2025-01-30 08:48:11.396 | SUCCESS  | __main__:<module>:39 - Endpoint is ready!
# 2025-01-30 08:48:11.397 | INFO     | __main__:<module>:40 - 	Vendor: aws
# 2025-01-30 08:48:11.397 | INFO     | __main__:<module>:41 - 	Instance: nvidia-l4
# 2025-01-30 08:48:11.398 | INFO     | __main__:<module>:42 - 	Batch Size: 8
# 2025-01-30 08:48:11.398 | INFO     | src.k6:optimal_vus:91 - Starting exponential search for optimal VUs
# 2025-01-30 08:48:11.398 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 1
# 2025-01-30 08:49:34.821 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_8_1.json
# 2025-01-30 08:49:34.822 | INFO     | src.k6:optimal_vus:96 - Throughput for 1 VUs: 3.00 req/sec
# 2025-01-30 08:49:34.822 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 2
# 2025-01-30 08:50:57.439 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_8_2.json
# 2025-01-30 08:50:57.440 | INFO     | src.k6:optimal_vus:96 - Throughput for 2 VUs: 4.59 req/sec
# 2025-01-30 08:50:57.440 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 4
# 2025-01-30 08:52:21.225 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_8_4.json
# 2025-01-30 08:52:21.226 | INFO     | src.k6:optimal_vus:96 - Throughput for 4 VUs: 4.80 req/sec
# 2025-01-30 08:52:21.226 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 8
# 2025-01-30 08:53:45.436 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_8_8.json
# 2025-01-30 08:53:45.437 | INFO     | src.k6:optimal_vus:96 - Throughput for 8 VUs: 4.25 req/sec
# 2025-01-30 08:53:45.437 | INFO     | src.k6:optimal_vus:100 - Throughput improvement is less than 2%, stopping exponential search.
# 2025-01-30 08:53:45.438 | INFO     | src.k6:optimal_vus:108 - Starting binary search refinement
# 2025-01-30 08:53:45.438 | INFO     | src.k6:optimal_vus:112 - Testing with VUs: 6
# 2025-01-30 08:55:09.922 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_8_6.json
# 2025-01-30 08:55:09.923 | INFO     | src.k6:optimal_vus:120 - Throughput did not improve with 6 VUs
# 2025-01-30 08:55:09.923 | INFO     | src.k6:optimal_vus:112 - Testing with VUs: 4
# 2025-01-30 08:55:09.926 | INFO     | src.k6:call_k6:42 - results file /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_8_4.json already exists
# 2025-01-30 08:55:09.927 | INFO     | src.k6:optimal_vus:120 - Throughput did not improve with 4 VUs
# 2025-01-30 08:55:09.928 | INFO     | src.k6:optimal_vus:123 - Optimal VUs: 4
# 2025-01-30 08:55:15.024 | SUCCESS  | __main__:<module>:39 - Endpoint is ready!
# 2025-01-30 08:55:15.024 | INFO     | __main__:<module>:40 - 	Vendor: aws
# 2025-01-30 08:55:15.025 | INFO     | __main__:<module>:41 - 	Instance: nvidia-l4
# 2025-01-30 08:55:15.025 | INFO     | __main__:<module>:42 - 	Batch Size: 16
# 2025-01-30 08:55:15.026 | INFO     | src.k6:optimal_vus:91 - Starting exponential search for optimal VUs
# 2025-01-30 08:55:15.026 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 1
# 2025-01-30 08:56:37.488 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_16_1.json
# 2025-01-30 08:56:37.489 | INFO     | src.k6:optimal_vus:96 - Throughput for 1 VUs: 2.99 req/sec
# 2025-01-30 08:56:37.490 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 2
# 2025-01-30 08:58:00.437 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_16_2.json
# 2025-01-30 08:58:00.438 | INFO     | src.k6:optimal_vus:96 - Throughput for 2 VUs: 4.54 req/sec
# 2025-01-30 08:58:00.439 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 4
# 2025-01-30 08:59:23.055 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_16_4.json
# 2025-01-30 08:59:23.055 | INFO     | src.k6:optimal_vus:96 - Throughput for 4 VUs: 4.80 req/sec
# 2025-01-30 08:59:23.056 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 8
# 2025-01-30 09:00:47.012 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_16_8.json
# 2025-01-30 09:00:47.013 | INFO     | src.k6:optimal_vus:96 - Throughput for 8 VUs: 4.14 req/sec
# 2025-01-30 09:00:47.014 | INFO     | src.k6:optimal_vus:100 - Throughput improvement is less than 2%, stopping exponential search.
# 2025-01-30 09:00:47.014 | INFO     | src.k6:optimal_vus:108 - Starting binary search refinement
# 2025-01-30 09:00:47.014 | INFO     | src.k6:optimal_vus:112 - Testing with VUs: 6
# 2025-01-30 09:02:11.575 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_16_6.json
# 2025-01-30 09:02:11.576 | INFO     | src.k6:optimal_vus:120 - Throughput did not improve with 6 VUs
# 2025-01-30 09:02:11.576 | INFO     | src.k6:optimal_vus:112 - Testing with VUs: 4
# 2025-01-30 09:02:11.579 | INFO     | src.k6:call_k6:42 - results file /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_16_4.json already exists
# 2025-01-30 09:02:11.580 | INFO     | src.k6:optimal_vus:120 - Throughput did not improve with 4 VUs
# 2025-01-30 09:02:11.580 | INFO     | src.k6:optimal_vus:123 - Optimal VUs: 4
# 2025-01-30 09:02:16.725 | SUCCESS  | __main__:<module>:39 - Endpoint is ready!
# 2025-01-30 09:02:16.725 | INFO     | __main__:<module>:40 - 	Vendor: aws
# 2025-01-30 09:02:16.725 | INFO     | __main__:<module>:41 - 	Instance: nvidia-l4
# 2025-01-30 09:02:16.726 | INFO     | __main__:<module>:42 - 	Batch Size: 32
# 2025-01-30 09:02:16.726 | INFO     | src.k6:optimal_vus:91 - Starting exponential search for optimal VUs
# 2025-01-30 09:02:16.727 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 1
# 2025-01-30 09:03:40.578 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_32_1.json
# 2025-01-30 09:03:40.579 | INFO     | src.k6:optimal_vus:96 - Throughput for 1 VUs: 2.98 req/sec
# 2025-01-30 09:03:40.579 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 2
# 2025-01-30 09:05:03.803 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_32_2.json
# 2025-01-30 09:05:03.804 | INFO     | src.k6:optimal_vus:96 - Throughput for 2 VUs: 4.55 req/sec
# 2025-01-30 09:05:03.804 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 4
# 2025-01-30 09:06:26.945 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_32_4.json
# 2025-01-30 09:06:26.945 | INFO     | src.k6:optimal_vus:96 - Throughput for 4 VUs: 4.81 req/sec
# 2025-01-30 09:06:26.946 | INFO     | src.k6:optimal_vus:93 - Testing with VUs: 8
# 2025-01-30 09:07:52.744 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_32_8.json
# 2025-01-30 09:07:52.745 | INFO     | src.k6:optimal_vus:96 - Throughput for 8 VUs: 4.30 req/sec
# 2025-01-30 09:07:52.745 | INFO     | src.k6:optimal_vus:100 - Throughput improvement is less than 2%, stopping exponential search.
# 2025-01-30 09:07:52.746 | INFO     | src.k6:optimal_vus:108 - Starting binary search refinement
# 2025-01-30 09:07:52.746 | INFO     | src.k6:optimal_vus:112 - Testing with VUs: 6
# 2025-01-30 09:09:17.125 | INFO     | src.k6:call_k6:75 - Results written to /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_32_6.json
# 2025-01-30 09:09:17.126 | INFO     | src.k6:optimal_vus:120 - Throughput did not improve with 6 VUs
# 2025-01-30 09:09:17.126 | INFO     | src.k6:optimal_vus:112 - Testing with VUs: 4
# 2025-01-30 09:09:17.129 | INFO     | src.k6:call_k6:42 - results file /home/ec2-user/encoder-analysis/results/vision-embedding/nvidia-l4/aws_nvidia-l4_default_torch_32_4.json already exists
# 2025-01-30 09:09:17.130 | INFO     | src.k6:optimal_vus:120 - Throughput did not improve with 4 VUs
# 2025-01-30 09:09:17.130 | INFO     | src.k6:optimal_vus:123 - Optimal VUs: 4

# %%
from src.process_dataset import load_json_files

# Define cost per hour considering both hardware type and vendor
cost_per_hour = {
    ('gcp', 'nvidia-t4'): 0.5,
    ('gcp', 'nvidia-l4'): 0.7,
    ('aws', 'nvidia-t4'): 0.5,
    ('aws', 'nvidia-l4'): 0.8,
}

# Load dataset
df = load_json_files('results/vision-embedding')

# Compute cost
df['seconds_per_billion'] = 1e9 / df['throughput_req_per_sec']
df['cost_per_sec'] = df.apply(lambda row: cost_per_hour.get((row['vendor'], row['hw_type']), 0) / 3600, axis=1)
df['1B_cost'] = df['seconds_per_billion'] * df['cost_per_sec']

df.sort_values(by='1B_cost').head()
# Out:
#     total_requests  test_duration_sec  successful_requests  avg_latency_ms  \
# 12             301          60.270528                  301      709.554817
# 2              292          60.472359                  292      736.383562
# 7              294          60.932410                  294      732.860544
# 27             293          60.945637                  293      734.651877
# 17             291          60.621261                  291      740.144330
#
#     p95_latency_ms  throughput_req_per_sec  avg_num_vectors  min_num_vectors  \
# 12         1222.00                4.994149       365.445183               81
# 2          1260.35                4.828652       365.832192               81
# 7          1275.95                4.825018       370.377551               81
# 27         1325.40                4.807563       368.901024               81
# 17         1333.00                4.800296       369.158076               81
#
#     max_num_vectors  invalid_embeddings    hw_type  batch_size  \
# 12              779                   0  nvidia-l4           4
# 2               779                   0  nvidia-l4           1
# 7               779                   0  nvidia-l4           2
# 27              779                   0  nvidia-l4          32
# 17              779                   0  nvidia-l4           8
#
#                          image engine vendor  vus  seconds_per_billion  \
# 12  michaelf34/infinity:0.0.75  torch    aws    4         2.002343e+08
# 2   michaelf34/infinity:0.0.75  torch    aws    4         2.070971e+08
# 7   michaelf34/infinity:0.0.75  torch    aws    4         2.072531e+08
# 27  michaelf34/infinity:0.0.75  torch    aws    4         2.080056e+08
# 17  michaelf34/infinity:0.0.75  torch    aws    4         2.083205e+08
#
#     cost_per_sec       1B_cost
# 12      0.000222  44496.514140
# 2       0.000222  46021.581982
# 7       0.000222  46056.243394
# 27      0.000222  46223.463621
# 17      0.000222  46293.441279

# %%
from datasets import Dataset
# Push to the hub
dataset = Dataset.from_pandas(df)
dataset.push_to_hub(HUB_DATASET_PATH)
# Out:
# Uploading the dataset shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Creating parquet from Arrow format:   0%|          | 0/1 [00:00<?, ?ba/s]
# CommitInfo(commit_url='https://huggingface.co/datasets/derek-thomas/vision-embedding-ie-optimization/commit/89224a3966ac6a03601c1f39227563281ab2aecc', commit_message='Upload dataset', commit_description='', oid='89224a3966ac6a03601c1f39227563281ab2aecc', pr_url=None, repo_url=RepoUrl('https://huggingface.co/datasets/derek-thomas/vision-embedding-ie-optimization', endpoint='https://huggingface.co', repo_type='dataset', repo_id='derek-thomas/vision-embedding-ie-optimization'), pr_revision=None, pr_num=None)
